# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruf0275/Machine-Learning-Notes/blob/main/Pandas/Important_DataFrame_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Important DataFrame Methods

# %%
import numpy as np
import pandas as pd
